# %% [markdown]
# #### Q. Explain GET and POST methods.

# %% [markdown]
# GET method is used to request data from a specified resource. The query string (name/value pairs) is sent in the URL of a GET request.
# Some points to mention:
# 1. GET requests are cached.
# 2. GET requests remain in the browser history and can be bookmarked.
#
# The POST method is used to send data to a server to create/update a resource. The data sent to the server with POST is stored in the request body of the HTTP request.
# Also,
# 1. POST requests are never cached.
# 2. POST requests do not remain in the browser history and cannot be bookmarked.

# %% [markdown]
# #### Q. Why is request used in Flask?

# %% [markdown]
# The request object contains all the data sent from the client to the server. And this data can be recovered using GET/POST methods.

# %% [markdown]
# #### Q. Why is redirect() used in Flask?

# %% [markdown]
# redirect is used to send the user to a particular URL with a status code. This status code additionally identifies the issue.

# %% [markdown]
# #### Q. What are templates in Flask? Why is the render_template() function used?

# %% [markdown]
# templates are used for making an user oriented interface and also to beautify the web interface.
#
# render_template() function is used to render a html page to user interface(visible to the user).

# %% [markdown]
# #### Q. Create a simple API. Use Postman to test it. Attach the screenshot of the output in the Jupyter Notebook.

# %% [markdown]
# ##### Calculator used to calculate power

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
